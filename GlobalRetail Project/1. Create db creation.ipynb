-- %%
%sql
create catalog if not exists globalretail;

-- %%
create database if not exists globalretail.gr_bronze;

-- %%
USE globalretail.gr_bronze;

-- %%
create database if not exists globalretail.gr_silver;

-- %%
create database if not exists globalretail.gr_gold;

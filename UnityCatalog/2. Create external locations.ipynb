# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dataricksucdl_bronze
URL 'abfss://bronze@databricksucproj26.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL access_connector);

# %%
dbutils.fs.ls("abfss://bronze@databricksucproj26.dfs.core.windows.net")

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dataricksucdl_silver
URL 'abfss://silver@databricksucproj26.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL access_connector);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dataricksucdl_gold
URL 'abfss://gold@databricksucproj26.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL access_connector);

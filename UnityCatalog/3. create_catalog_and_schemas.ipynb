# %%
# %sql
create catalog if not exists formula1_dev

# %%
# %sql
use catalog formula1_dev

# %%
# %sql
create schema if not exists bronze
managed location "abfss://bronze@databricksucproj26.dfs.core.windows.net"

# %%
# %sql
create schema if not exists silver
managed location "abfss://silver@databricksucproj26.dfs.core.windows.net"

# %%
# %sql
create schema if not exists gold
managed location "abfss://gold@databricksucproj26.dfs.core.windows.net"

# %%
account_key = dbutils.secrets.get(scope='databricks-scope' ,key = 'databricks-strg-access-key' )

# %%
spark.conf.set("fs.azure.account.key.databricksrg2026.dfs.core.windows.net",account_key)

# %%
race_results_df = spark.read.parquet("abfss://presentation@databricksrg2026.dfs.core.windows.net/")

# %% [markdown]
# **Create temp view on top of the df**

# %%
race_results_df.createTempView("v_race_results")

# %%
# %sql
select * from v_race_results where race_year = '2020'

# %% [markdown]
# **run sql cell from a python **notebook****

# %%
race_results_sql = spark.sql("select * from v_race_results where race_year ='2020'")

# %%
display(race_results_sql)

# %%
p_race_year = '2019'

# %%
race_results_sql = spark.sql(f"select * from v_race_results where race_year = {p_race_year}")

# %%
race_results_df.createOrReplaceTempView("v_race_results")

# %%
# %sql
select count(*) from v_race_results where race_year = '2020'

-- %%
show databases

-- %%
select current_database()

-- %%
use f1_raw

-- %%
select * from races

-- %%
desc f1_raw.drivers

-- %%
select * from drivers limit 10;

-- %%
select * from drivers where nationality = "British" and dob >= '1990-01-01' order by dob desc

-- %% [markdown]
-- **Functions**

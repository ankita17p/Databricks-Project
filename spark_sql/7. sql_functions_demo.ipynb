-- %%
use f1_processed

-- %%
select * , concat(driverRef,'_',code) as new_driver_ref
 from f1_raw.drivers

-- %%
select *, split(concat(name.forename, ' ', name.surname), ' ')
from f1_raw.drivers

-- %%
select *, date_format(dob, 'dd-MM-yyyy') as birthDate_new
from f1_raw.drivers

-- %%
select count(*) from f1_raw.drivers

-- %%
select max(dob) from f1_raw.drivers

-- %%
select nationality, count(*) from f1_raw.drivers
group by nationality
having count(*) > 100
order by count(*) desc

-- %%
select nationality, name, dob, RANK() over(partition by nationality order by dob desc) as age_rank
from f1_raw.drivers
